# %% [markdown]
# <a href="https://colab.research.google.com/github/katerinbarrera21/Simulacion/blob/main/tareas2/07EstadisticaDescriptiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tarea 07 - Introducción a la Probabilidad

# %%
import numpy as np
import pandas as pd 
from scipy import stats
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/archivosSimulacion2	
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/archivosSimulacion2
#  09simulacionLavadoCarros3tiposConRetraso.ipynb   examenSimulacion.ipynb
#  10trabajoCOVID.ipynb				  fifa_datos.csv
# 'Copia de PruebaCorrección.ipynb'		  PruebaCorrección.ipynb
#  dataset-sri-resumen-v2.csv			  pruebaSimulacionSimpy.ipynb
#  ExamenSimu.ipynb

# %%
data_fifa = pd.read_csv('fifa_datos.csv')
data_empleo= pd.read_csv('dataset-sri-resumen-v2.csv')

# %%
data_fifa = data_fifa.drop(['Unnamed: 0'], axis=1)
data_fifa.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
data_empleo.head()
# Out:
#    Ranking (1) Tamaño  2021  Ranking (1) Tamaño  2020  \
# 0                         1                         1
# 1                         2                         2
# 2                         3                         3
# 3                         4                         5
# 4                         5                         4
#
#    Variación Ranking Tamaño 2020 - 2021 NUEVO GE  \
# 0                                     0      NaN
# 1                                     0      NaN
# 2                                     0      NaN
# 3                                     1      NaN
# 4                                    -1      NaN
#
#                               Nombre Grupo Económico  \
# 0  BANCO PICHINCHA (DINERS CLUB DEL ECUADOR, BANC...
# 1  ALMACENES JUAN ELJURI (BANCO DEL AUSTRO, AEKIA...
# 2  CORPORACIÓN FAVORITA (COMERCIAL KIWY, SUKASA, ...
# 3  BANCO DE GUAYAQUIL (CORPORACION MULTIBG, FIDEI...
# 4  SCHLUMBERGER DEL ECUADOR (CONSORCIO SHUSHUFIND...
#
# ...

# %%
data_fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Special                   18207 non-null  int64
# ...

# %%
data_empleo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 40 columns):
#  #   Column                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                        --------------  -----
#  0   Ranking (1) Tamaño  2021                                                                                      302 non-null    int64
#  1   Ranking (1) Tamaño  2020                                                                                      302 non-null    int64
#  2   Variación Ranking Tamaño 2020 - 2021                                                                          302 non-null    int64
#  3   NUEVO GE                                                                                                      49 non-null     object
# ...

# %%
data_fifa.describe(include=['int64'])
# Out:
#                   ID           Age       Overall     Potential       Special
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000

# %%
data_empleo.describe(include=['int64'])
# Out:
#        Ranking (1) Tamaño  2021  Ranking (1) Tamaño  2020  \
# count                302.000000                302.000000
# mean                 151.500000                151.500000
# std                   87.324109                 87.324109
# min                    1.000000                  1.000000
# 25%                   76.250000                 76.250000
# 50%                  151.500000                151.500000
# 75%                  226.750000                226.750000
# max                  302.000000                302.000000
#
#        Variación Ranking Tamaño 2020 - 2021  \
# count                            302.000000
# mean                               0.000000
# std                               14.639182
# min                              -85.000000
# 25%                               -5.750000
# 50%                                1.000000
# 75%                                7.750000
# max                               49.000000
#
# ...

# %%
data_fifa.describe(include=['float64'])
# Out:
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# 25%                    1.000000      3.000000      2.000000       8.000000
# 50%                    1.000000      3.000000      2.000000      17.000000
# 75%                    1.000000      3.000000      3.000000      26.000000
# max                    5.000000      5.000000      5.000000      99.000000
#
#            Crossing     Finishing  HeadingAccuracy  ShortPassing  \
# count  18159.000000  18159.000000     18159.000000  18159.000000
# mean      49.734181     45.550911        52.298144     58.686712
# std       18.364524     19.525820        17.379909     14.699495
# ...

# %%
data_empleo.describe(include=['float64'])
# Out:
#        Instituciones Financieras (2)  Medios de Comunicación (3)  \
# count                      32.000000                   27.000000
# mean                        1.406250                    2.037037
# std                         1.131923                    1.675192
# min                         1.000000                    1.000000
# 25%                         1.000000                    1.000000
# 50%                         1.000000                    1.000000
# 75%                         1.000000                    2.000000
# max                         6.000000                    8.000000
#
#        Variación Ranking Contribución I.R. 2019-2020  \
# count                                     299.000000
# mean                                        0.618729
# std                                        69.976759
# min                                      -297.000000
# 25%                                       -21.500000
# 50%                                        10.000000
# ...

# %%
data_fifa.describe(include=[object])
# Out:
#                 Name                                           Photo  \
# count          18207                                           18207
# unique         17194                                           18207
# top     J. Rodríguez  https://cdn.sofifa.org/players/4/19/158023.png
# freq              11                                               1
#
#        Nationality                                 Flag          Club  \
# count        18207                                18207         17966
# unique         164                                  164           651
# top        England  https://cdn.sofifa.org/flags/14.png  FC Barcelona
# freq          1662                                 1662            33
#
#                                            Club Logo  Value   Wage  \
# count                                          18207  18207  18207
# unique                                           679    217    144
# ...

# %%
data_empleo.describe(include=[object])
# Out:
#        NUEVO GE                             Nombre Grupo Económico  \
# count        49                                                302
# unique        1                                                302
# top           X  BANCO PICHINCHA (DINERS CLUB DEL ECUADOR, BANC...
# freq         49                                                  1
#
#        Reporta sus BENEFICIARIOS EFECTIVOS (*) Contribución I.R. 2020  \
# count                                      302                    302
# unique                                       3                    286
# top                                         SI                     0%
# freq                                       202                     17
#
#        Contribución I.R. 2019  Variación Ingresos  \
# count                     302                 302
# unique                    300                 302
# top                        0%  -8.09080697942649%
# freq                        3                   1
#
# ...

# %%
sns.heatmap(data_fifa.corr())

# %%
sns.heatmap(data_empleo.corr())

# %% [markdown]
# Conclusiones y recomendaciones
#
# Es necesario considerar que al analizar conjuntos de datos extensos, con cantidades considerables de información es conveniente, realizar un proceso de análisis, claro que se debe tener en consideración algunos puntos, por ejemplo el nombre de las columnas, el tipo de dato que esta siendo manejado dentro de una columna como los valores que presenta. Y algo muy importante y relevante es el tratamiento que se proporciona a las celdas vacías, y todas las consideraciones que se deben tener presentes para tomar una decisión acertada sobre que proceso se seguirá con este tipo de celdas.
#
# Entonces se concluye que las herramientas existentes para poder realizar un ánilisis descriptivo con Python, sobre un cojunto de datos es realmente relevante y proporciona una gran ayuda para poder trabajar sobre datos, con el fin de que se pueda comprender mejor los datos, caracteristicas o relaciones que existen o pueden existir para realizar un estudio o plantear ciertas hipotesis.
#
# Se tiene en cuenta que, los datos deben ser ordenados, clasificados, tratados y mejorados para poder obtener una clara visualización de la información.
